# %%
import numpy as np


import pandas as pd

from sklearn.datasets import load_iris

# %%
iris= load_iris()
dir(iris)
# Out:
# ['DESCR',
#  'data',
#  'data_module',
#  'feature_names',
#  'filename',
#  'frame',
#  'target',
#  'target_names']

# %%
data= pd.DataFrame(iris.data, columns=iris.feature_names)
data.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2

# %%
#addd atget 
data['target']= iris.target

# %%
data.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#    target
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0

# %%
#conmnvert target to respective names

data['target'] = data.target.apply(lambda x: iris.target_names[x])
data.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#    target
# 0  setosa
# 1  setosa
# 2  setosa
# 3  setosa
# 4  setosa

# %%
data.head
# Out:
# <bound method NDFrame.head of      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
# ...

# %%
# we ahve cross val to check whch is the bes 

from sklearn.model_selection import  cross_val_score

from sklearn.svm import SVC

#do sv,m method for few parameters lambda, c etc

# %%
val=cross_val_score(SVC(kernel='linear', C=10, gamma='auto'),iris.data,data.target,cv=5)
avg= val.mean()
avg
# Out:
# np.float64(0.9733333333333334)

# %%
val = cross_val_score(SVC(kernel='sigmoid', C=10, gamma='auto'),
                iris.data, data.target, cv=5)
avg = val.mean()
avg
# Out:
# np.float64(0.09333333333333334)

# %%
val = cross_val_score(SVC(kernel='rbf', C=10, gamma='auto'),
                iris.data, data.target, cv=5)
avg = val.mean()
avg
# Out:
# np.float64(0.9800000000000001)

# %%
# To know tjhe optimal hypermeter need to do manually

#or use for loop

kernels = [ 'linear','sigmoid','rbf']
C=[1,10,20]
avg_scores= { }

for kval in kernels:
    for c in C:
        val = cross_val_score(SVC(kernel=kval, C=c, gamma='auto'),
                          iris.data, data.target, cv=5)
        avg = val.mean()
        print("The avg for {} is {}".format(kval,avg))
# Out:
# The avg for linear is 0.9800000000000001
# The avg for linear is 0.9733333333333334
# The avg for linear is 0.9666666666666666
# The avg for sigmoid is 0.09333333333333334
# The avg for sigmoid is 0.09333333333333334
# The avg for sigmoid is 0.09333333333333334
# The avg for rbf is 0.9800000000000001
# The avg for rbf is 0.9800000000000001
# The avg for rbf is 0.9666666666666668

# %%
# thsi is also lengthy need to manaully give C 

#here comes gridSearchCV

from sklearn.model_selection import GridSearchCV

Gsv= GridSearchCV(SVC(gamma='auto'),{
    #parameter grid
    'C':[1,10,20],
    'kernel':['linear','rbf','sigmoid'],
},cv=5, return_train_score=False)  #False because we dont neeed parameter that it retrurn


Gsv.fit(iris.data,data.target)
Gsv.cv_results_
# Out:
# {'mean_fit_time': array([0.00231485, 0.00179911, 0.00180016, 0.00120058, 0.00160069,
#         0.00240088, 0.00119963, 0.00120091, 0.00220141]),
#  'std_fit_time': array([0.00075307, 0.0003996 , 0.0007481 , 0.00040107, 0.00049033,
#         0.00049203, 0.00040011, 0.00040031, 0.00040384]),
#  'mean_score_time': array([0.00138564, 0.00120196, 0.00119972, 0.00119901, 0.00059967,
#         0.00100007, 0.00019994, 0.00099974, 0.00119953]),
#  'std_score_time': array([4.72681688e-04, 7.48943666e-04, 4.01140404e-04, 4.01739112e-04,
#         4.89629141e-04, 1.37871097e-06, 3.99875641e-04, 1.79305989e-06,
#         4.00661593e-04]),
#  'param_C': masked_array(data=[1, 1, 1, 10, 10, 10, 20, 20, 20],
#               mask=[False, False, False, False, False, False, False, False,
#                     False],
#         fill_value=999999),
#  'param_kernel': masked_array(data=['linear', 'rbf', 'sigmoid', 'linear', 'rbf', 'sigmoid',
#                     'linear', 'rbf', 'sigmoid'],
# ...

# %%
# All with the answer and mewan, 
#to study the result pandas provided a library

df = pd.DataFrame(Gsv.cv_results_)
df
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time  param_C  \
# 0       0.002315      0.000753         0.001386        0.000473        1
# 1       0.001799      0.000400         0.001202        0.000749        1
# 2       0.001800      0.000748         0.001200        0.000401        1
# 3       0.001201      0.000401         0.001199        0.000402       10
# 4       0.001601      0.000490         0.000600        0.000490       10
# 5       0.002401      0.000492         0.001000        0.000001       10
# 6       0.001200      0.000400         0.000200        0.000400       20
# 7       0.001201      0.000400         0.001000        0.000002       20
# 8       0.002201      0.000404         0.001200        0.000401       20
#
#   param_kernel                          params  split0_test_score  \
# 0       linear    {'C': 1, 'kernel': 'linear'}           0.966667
# 1          rbf       {'C': 1, 'kernel': 'rbf'}           0.966667
# ...

# %%
#not need all of this so just trim what is important

df[['param_C','param_kernel','mean_test_score']]
# Out:
#    param_C param_kernel  mean_test_score
# 0        1       linear         0.980000
# 1        1          rbf         0.980000
# 2        1      sigmoid         0.093333
# 3       10       linear         0.973333
# 4       10          rbf         0.980000
# 5       10      sigmoid         0.093333
# 6       20       linear         0.966667
# 7       20          rbf         0.966667
# 8       20      sigmoid         0.093333

# %%
#based on this i can say I can provide 0, 1, 4 as hyper parameter
#lets see what else is there in model\


dir(Gsv)
# Out:
# ['__abstractmethods__',
#  '__annotations__',
#  '__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__setstate__',
#  '__sizeof__',
#  '__sklearn_clone__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_abc_impl',
#  '_build_request_for_signature',
#  '_check_feature_names',
#  '_check_n_features',
#  '_check_refit_for_multimetric',
#  '_doc_link_module',
#  '_doc_link_template',
#  '_doc_link_url_param_generator',
#  '_estimator_type',
#  '_format_results',
#  '_get_default_requests',
#  '_get_doc_link',
#  '_get_metadata_request',
#  '_get_param_names',
#  '_get_routed_params_for_fit',
#  '_get_scorers',
#  '_get_tags',
#  '_more_tags',
# ...

# %%
#to know best score 
Gsv.best_score_
# Out:
# np.float64(0.9800000000000001)

# %%
#best params

Gsv.best_params_
# Out:
# {'C': 1, 'kernel': 'linear'}

# %%
# but theres is an issue here what is c value is in millions
# millions of permutaion and computation has to be run
# increase in omputation cost
# nCm is te computation where ab=ba
# cpm is permutation where ab != ba


# to tackle the issue introduced random search cv
from sklearn.model_selection import RandomizedSearchCV

rs = RandomizedSearchCV(SVC(gamma='auto'), {
    # parameter grid
    'C': [1, 10, 20],
    'kernel': ['linear', 'rbf', 'sigmoid'],
}, cv=5, return_train_score=False,
    n_iter=2)

#n_iter is the number of ietration before if there is a rbf and C=[10,0,20] the iteration runs for all 3 C'set
#but now just 2 random

# %%
rs.fit(iris.data,data.target)
# Out:
# RandomizedSearchCV(cv=5, estimator=SVC(gamma='auto'), n_iter=2,
#                    param_distributions={'C': [1, 10, 20],
#                                         'kernel': ['linear', 'rbf', 'sigmoid']})

# %%
val= pd.DataFrame(rs.cv_results_)[['param_C','param_kernel','mean_test_score']]
val
# Out:
#    param_C param_kernel  mean_test_score
# 0        1      sigmoid         0.093333
# 1        1          rbf         0.980000

# %%
val.shape
# Out:
# (2, 3)

# %%
# how to choose the best model for optimal performance

# what I want to test RF, LogisticRegression, svc etc etc


from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier




model_params = {
    'svm': {
        'model': SVC(gamma='auto'),
        'params': {
            'C': [1, 10, 20],
            'kernel': ['rbf,linear', 'sigmoid']
        }
    },
    'Logistic_regression': {
        'model':LogisticRegression(solver='liblinear',multi_class ='auto'),
        'params':{
            'C': [1,5,10]
        }

    },
    'random_forest':{
        'model':RandomForestClassifier(),
        'params':{
            'n_estimators':[1,5,10]
        }
    }

}

# %%
# use RandomSeacrch hypermeter Cv

scores = []

for model_name, mp in model_params.items():
    clf = GridSearchCV(mp['model'], mp['params'],
                       cv=5, return_train_score=False)
    clf.fit(iris.data, iris.target)
    scores.append(
        {
            'model': model_name,
            'best_score': clf.best_score_,
            'best_params': clf.best_params_
        }
    )

print('The score of all is {}'.format(scores))
# Out:
# c:\Users\ghoas\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\model_selection\_validation.py:540: FitFailedWarning:
# 15 fits failed out of a total of 30.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 15 fits failed with the following error:
# Traceback (most recent call last):
#   File "c:\Users\ghoas\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\model_selection\_validation.py", line 888, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "c:\Users\ghoas\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py", line 1466, in wrapper
#     estimator._validate_params()
# ...

# %%
data = pd.DataFrame(scores)
data
# Out:
#                  model  best_score                    best_params
# 0                  svm    0.093333  {'C': 1, 'kernel': 'sigmoid'}
# 1  Logistic_regression    0.966667                       {'C': 5}
# 2        random_forest    0.966667            {'n_estimators': 5}
